# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression

from scipy.stats import pearsonr
import numpy as np

data = pd.read_csv("EVI-Green.csv")
data.head(5)
# Out:
#    Green       EVI
# 0   4262  0.726231
# 1   2290  0.435306
# 2    914  0.300242
# 3   1045  0.323778
# 4    490  0.367599

# %%
# Perform Linear Regression
x = data['EVI'].values.reshape(-1, 1)
y = data['Green'].values
model = LinearRegression().fit(x, y)

# Predict the Biomass using the model for the line
predictions = model.predict(x)

# Calculate R squared
r_squared = model.score(x, y)

# Create the scatter plot, ensuring that the 'Biomass' data is divided by 1000
fig, ax = plt.subplots(figsize=[7, 7])
sns.scatterplot(x='EVI', y=data['Green'] / 1000, data=data, ax=ax)

# Plot the regression line
ax.plot(data['EVI'], predictions / 1000, color='red')

# Set the axis labels
ax.set_xlabel('EVI')
ax.set_ylabel('Green (kg DM/ha x 10³)')  # Using 'x' for multiplication symbol

# Set x and y limits
ax.set_xlim([0, 1])
ax.set_ylim([0, max(data['Green']) / 1000])

# Add text with only the R squared value
ax.text(0.01, max(data['Green']) / 1000 * 0.95, f'R² = {r_squared:.2f}', fontsize=11,
        verticalalignment='top', horizontalalignment='left')

# Remove the legend if it's not needed
ax.legend().remove()
#ax.set_ylim([0, (max(data['Green']) / 1000) + 1])

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr, shapiro
import numpy as np

# Load data
data = pd.read_csv("EVI-Green.csv")

# Extract variables
x = data['EVI'].values.reshape(-1, 1)
y = data['Green'].values

# %%
#from scipy.stats import boxcox
#data['EVI_transformed'], _ = boxcox(data['EVI'] + 1)  # Adding 1 to handle zero values

data['EVI_log'] = np.log1p(data['EVI'])  # log1p handles zero values
data['Green_log'] = np.log1p(data['Green'])

# %%
# Perform Shapiro-Wilk test for normality (Reviewer Comment 1)
shapiro_test_x = shapiro(data['EVI'])
shapiro_test_y = shapiro(data['Green'])

print(f"Shapiro-Wilk test for EVI: p-value = {shapiro_test_x.pvalue:.4f}")
print(f"Shapiro-Wilk test for Green: p-value = {shapiro_test_y.pvalue:.4f}")
# Out:
# Shapiro-Wilk test for EVI: p-value = 0.0139
# Shapiro-Wilk test for Green: p-value = 0.0001

# %%
# Compute Pearson Correlation (Reviewer Comment 2)
pearson_corr, pearson_p = pearsonr(data['EVI'], data['Green'])
print(f"Pearson correlation coefficient: {pearson_corr:.2f}, p-value: {pearson_p:.4f}")
# Out:
# Pearson correlation coefficient: 0.49, p-value: 0.0026

# %%
# Perform Linear Regression (Model Training)
model = LinearRegression().fit(x, y)
predictions = model.predict(x)

# Calculate Performance Metrics (Reviewer Comment 3)
r_squared = model.score(x, y)
rmse = np.sqrt(mean_squared_error(y, predictions))  # RMSE
mae = mean_absolute_error(y, predictions)  # MAE

# Create scatter plot
fig, ax = plt.subplots(figsize=[7, 7])
sns.scatterplot(x='EVI', y=data['Green'] / 1000, data=data, ax=ax)

# Plot regression line
ax.plot(data['EVI'], predictions / 1000, color='red', label='Regression Line')

# Set labels
ax.set_xlabel('EVI')
ax.set_ylabel('Green Biomass (kg DM/ha × 10³)')

# Set x and y limits
ax.set_xlim([0, 1])
ax.set_ylim([0, max(data['Green']) / 1000 + 1])

# Add text with R², RMSE, and MAE (Now Defined Correctly)
metrics_text = f'R² = {r_squared:.2f}\nRMSE = {rmse/1000:.2f}\nMAE = {mae/1000:.2f}'
ax.text(0.01, max(data['Green']) / 1000 * 1.15, metrics_text, fontsize=11, 
        verticalalignment='top', horizontalalignment='left')

# Add Pearson Correlation text
pearson_text = f'Pearson r = {pearson_corr:.2f}, p = {pearson_p:.4f}'
ax.text(0.01, max(data['Green']) / 1000 * 1.04, pearson_text, fontsize=11, 
        verticalalignment='top', horizontalalignment='left')

# Move legend to avoid overlap
ax.legend(loc='upper right')

# Save the Plot as JPEG
plt.savefig("EVI_Green_Plot.jpg", format="jpeg", dpi=300, bbox_inches="tight")

# Show plot
plt.show()

# %%
import scipy.stats as stats
residuals = y - model.predict(x)
shapiro_test = stats.shapiro(residuals)
print(f"Shapiro-Wilk test for residuals: p-value = {shapiro_test.pvalue}")
# Out:
# Shapiro-Wilk test for residuals: p-value = 3.2368051920972613e-05

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

residuals = y - predictions  # Compute residuals
stats.probplot(residuals, dist="norm", plot=plt)
plt.title("QQ Plot of Residuals")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pygam import LinearGAM, s

# Load the dataset
data = pd.read_csv("EVI-Green.csv")

data.head(5)
# Out:
#    Green       EVI
# 0   4262  0.726231
# 1   2290  0.435306
# 2    914  0.300242
# 3   1045  0.323778
# 4    490  0.367599

# %%
# Define independent (X) and dependent (Y) variables
X = data['EVI'].values.reshape(-1, 1)
Y = data['Green'].values

# Fit Generalized Additive Model (GAM) with smoothing
gam = LinearGAM(s(0)).fit(X, Y)

# Generate predictions
X_grid = np.linspace(X.min(), X.max(), 100)
Y_pred = gam.predict(X_grid)

# Scatter plot of original data
plt.scatter(X, Y, label='Data', color='blue')

# Plot GAM smooth curve
plt.plot(X_grid, Y_pred, label='GAM Fit', color='red')

# Labels and legend
plt.xlabel("EVI")
plt.ylabel("Green Biomass (kg DM/ha)")
plt.legend()
plt.title("GAM Fit: EVI vs Green Biomass")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from pygam import LinearGAM, s

# Load the dataset
data = pd.read_csv("EVI-Green.csv")

data.head(5)
# Out:
#    Green       EVI
# 0   4262  0.726231
# 1   2290  0.435306
# 2    914  0.300242
# 3   1045  0.323778
# 4    490  0.367599

# %%
# Define independent (X) and dependent (Y) variables
X = data[['EVI']].values
Y = data['Green'].values

# Fit Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X, Y)
Y_pred_linear = linear_model.predict(X)

# Fit Generalized Additive Model (GAM)
gam = LinearGAM(s(0)).fit(X, Y)

# Generate smooth predictions for GAM (Sort X values before prediction)
X_sorted = np.sort(X, axis=0)  # Sort X values for a smooth curve
Y_pred_gam = gam.predict(X_sorted)  # Predict for sorted X

# Compute performance metrics
r2_linear = r2_score(Y, Y_pred_linear)
rmse_linear = np.sqrt(mean_squared_error(Y, Y_pred_linear))
mae_linear = mean_absolute_error(Y, Y_pred_linear)

r2_gam = r2_score(Y, gam.predict(X))  # Use original X for R² calculation
rmse_gam = np.sqrt(mean_squared_error(Y, gam.predict(X)))
mae_gam = mean_absolute_error(Y, gam.predict(X))

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(X, Y, color='blue')

# Plot Linear Regression line
plt.plot(X, Y_pred_linear, color='red', label="Linear Regression Fit")

# Plot GAM curve (smooth)
plt.plot(X_sorted, Y_pred_gam, color='green', label="GAM Fit")

# Add performance metrics at the top-right inside the plot
metrics_text = (
    f"Linear Regression -> R²: {r2_linear:.2f}, RMSE: {rmse_linear:.2f}, MAE: {mae_linear:.2f}\n"
    f"GAM Model -> R²: {r2_gam:.2f}, RMSE: {rmse_gam:.2f}, MAE: {mae_gam:.2f}"
)
plt.text(0.3, max(Y) * 1.05, metrics_text, fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Add the legend directly below the metrics
plt.legend(loc='upper left', bbox_to_anchor=(0.01, 0.85))  # Adjusted position to align below the text


# Labels and legend
plt.xlabel("EVI")
plt.ylabel("Green Biomass (kg DM/ha)")
#plt.title("MODEL PERFORMANCE COMPARISON")

# Move legend to bottom right
plt.legend(loc="lower right")

# Show plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pygam import LinearGAM, s
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load the dataset
data = pd.read_csv("EVI-Green.csv")

# Define independent (X) and dependent (Y) variables
X = data[['EVI']].values
Y = data['Green'].values

# Fit Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X, Y)
Y_pred_linear = linear_model.predict(X)

# Fit Generalized Additive Model (GAM)
gam = LinearGAM(s(0)).fit(X, Y)

# Generate smooth predictions for GAM (Sort X values before prediction)
X_sorted = np.sort(X, axis=0)  # Sort X values for a smooth curve
Y_pred_gam = gam.predict(X_sorted)  # Predict for sorted X

# Compute performance metrics
r2_linear = r2_score(Y, Y_pred_linear)
rmse_linear = np.sqrt(mean_squared_error(Y, Y_pred_linear))
mae_linear = mean_absolute_error(Y, Y_pred_linear)

r2_gam = r2_score(Y, gam.predict(X))  # Use original X for R² calculation
rmse_gam = np.sqrt(mean_squared_error(Y, gam.predict(X)))
mae_gam = mean_absolute_error(Y, gam.predict(X))

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(X, Y, color='blue')

# Plot Linear Regression line
plt.plot(X, Y_pred_linear, color='red', label="Linear Regression Fit")

# Plot GAM curve (smooth)
plt.plot(X_sorted, Y_pred_gam, color='green', label="GAM Fit")

# Add performance metrics at the top-right inside the plot
metrics_text = (
    f"Linear Regression -> R²: {r2_linear:.2f}, RMSE: {rmse_linear:.2f}, MAE: {mae_linear:.2f}\n"
    f"GAM Model -> R²: {r2_gam:.2f}, RMSE: {rmse_gam:.2f}, MAE: {mae_gam:.2f}"
)
plt.text(0.3, max(Y) * 1.02, metrics_text, fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Add the legend directly below the metrics
plt.legend(loc='upper left', bbox_to_anchor=(0.03, 0.9))  # Adjusted position to align below the text

# Labels and legend
plt.xlabel("EVI")
plt.ylabel("Green Biomass (kg DM/ha)")
#plt.title("MODEL PERFORMANCE COMPARISON")

# Save the Plot as JPEG
plt.savefig("EVI_Green-GAM_Plot.jpg", format="jpeg", dpi=300, bbox_inches="tight")

# Show plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pygam import LinearGAM, s
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load the dataset
data = pd.read_csv("EVI-Green.csv")

# Define independent (X) and dependent (Y) variables
X = data[['EVI']].values
Y = data['Green'].values

# Fit Linear Regression model
linear_model = LinearRegression()
linear_model.fit(X, Y)
Y_pred_linear = linear_model.predict(X)

# Fit Generalized Additive Model (GAM)
gam = LinearGAM(s(0)).fit(X, Y)

# Generate smooth predictions for GAM (Sort X values before prediction)
X_sorted = np.sort(X, axis=0)
Y_pred_gam = gam.predict(X_sorted)

# Compute performance metrics
r2_linear = r2_score(Y, Y_pred_linear)
rmse_linear = np.sqrt(mean_squared_error(Y, Y_pred_linear))
mae_linear = mean_absolute_error(Y, Y_pred_linear)

r2_gam = r2_score(Y, gam.predict(X))
rmse_gam = np.sqrt(mean_squared_error(Y, gam.predict(X)))
mae_gam = mean_absolute_error(Y, gam.predict(X))

# Set plot
plt.figure(figsize=(8, 6))
plt.scatter(X, Y, color='blue', s=40)

# Plot Linear Regression line
plt.plot(X, Y_pred_linear, color='red', linewidth=2.5, label="Linear Regression Fit")

# Plot GAM curve (smooth)
plt.plot(X_sorted, Y_pred_gam, color='green', linewidth=2.5, label="GAM Fit")

# Add performance metrics first
metrics_text = (
    f"Linear Regression → R²: {r2_linear:.2f}, RMSE: {rmse_linear:.2f}, MAE: {mae_linear:.2f}\n"
    f"GAM Model → R²: {r2_gam:.2f}, RMSE: {rmse_gam:.2f}, MAE: {mae_gam:.2f}"
)

# First metrics text, then legend right underneath it
# We adjust metrics text a bit higher so the legend can sit nicely below

plt.text(0.30, max(Y) * 1.02, metrics_text,
         fontsize=10, fontweight='bold',
         verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Now position the legend manually below the metrics box
plt.legend(loc='upper left', bbox_to_anchor=(0.03, 0.9), fontsize=10, frameon=True)

# Labels
plt.xlabel("EVI", fontsize=16, fontweight='bold')
plt.ylabel("Green Biomass (kg DM/ha)", fontsize=16, fontweight='bold')
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

# Save the plot
plt.savefig("EVI_Green-GAM_Plot_highres_final.jpg", format="jpeg", dpi=600, bbox_inches="tight")

# Show plot
plt.show()
